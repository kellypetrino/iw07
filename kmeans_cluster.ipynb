# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
import numpy as np

# %%
# Read in metadata
meta = pd.read_csv("metadata.csv")
meta["DATE"] = pd.to_datetime(meta["DATE"])
meta = meta.drop_duplicates()
meta.index = range(len(meta))
meta
# Out:
#            DATE WDW_TICKET_SEASON  DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  \
# 0    2015-01-01               NaN          5          0           0
# 1    2015-01-02               NaN          6          1           0
# 2    2015-01-03               NaN          7          2           0
# 3    2015-01-04               NaN          1          3           1
# 4    2015-01-05               NaN          2          4           1
# ...         ...               ...        ...        ...         ...
# 1820 2019-12-26               NaN          5        359          51
# 1821 2019-12-27               NaN          6        360          51
# 1822 2019-12-28               NaN          7        361          51
# 1823 2019-12-29               NaN          1        362          52
# 1824 2019-12-30               NaN          2        363          52
#
#       MONTHOFYEAR  YEAR          SEASON  HOLIDAYPX  HOLIDAYM  ... HSFIREWKS  \
# 0               1  2015  CHRISTMAS PEAK          0         5  ...         1
# 1               1  2015       CHRISTMAS          2         5  ...         1
# 2               1  2015       CHRISTMAS          3         0  ...         1
# 3               1  2015       CHRISTMAS          4         0  ...         1
# 4               1  2015       CHRISTMAS          5         0  ...         1
# ...           ...   ...             ...        ...       ...  ...       ...
# 1820           12  2019       CHRISTMAS          2         5  ...         1
# 1821           12  2019  CHRISTMAS PEAK          3         5  ...         1
# 1822           12  2019  CHRISTMAS PEAK          4         5  ...         1
# 1823           12  2019  CHRISTMAS PEAK          3         5  ...         1
# 1824           12  2019  CHRISTMAS PEAK          2         5  ...         1
#
#       AKPRDDAY AKPRDDT1 AKPRDDT2 AKPRDDN  AKFIREN  AKSHWNGT AKSHWNT1  \
# 0            0      NaN      NaN     NaN      NaN         0      NaN
# 1            0      NaN      NaN     NaN      NaN         0      NaN
# 2            0      NaN      NaN     NaN      NaN         0      NaN
# 3            0      NaN      NaN     NaN      NaN         0      NaN
# 4            0      NaN      NaN     NaN      NaN         0      NaN
# ...        ...      ...      ...     ...      ...       ...      ...
# 1820         0      NaN      NaN     NaN      NaN         2    18:30
# 1821         0      NaN      NaN     NaN      NaN         3    18:30
# 1822         0      NaN      NaN     NaN      NaN         3    18:30
# 1823         0      NaN      NaN     NaN      NaN         3    18:30
# 1824         0      NaN      NaN     NaN      NaN         3    18:30
#
#       AKSHWNT2          AKSHWNN
# 0          NaN              NaN
# 1          NaN              NaN
# 2          NaN              NaN
# 3          NaN              NaN
# 4          NaN              NaN
# ...        ...              ...
# 1820     20:00  Rivers of Light
# 1821     20:00  Rivers of Light
# 1822     20:00  Rivers of Light
# 1823     20:00  Rivers of Light
# 1824     20:00  Rivers of Light
#
# [1825 rows x 190 columns]

# %%
# Convert seasons to ints in metadata
for i in range(len(meta20)):
    v = meta20.iloc[i]['SEASON']
    if v == 'CHRISTMAS':
        v = 1
    elif v == 'CHRISTMAS PEAK':
        v = 2
    elif v == 'COLUMBUS DAY':
        v = 3
    elif v == 'EASTER':
        v = 4
    elif v == 'FALL':
        v = 5
    elif v == 'HALLOWEEN':
        v = 6
    elif v == 'JERSEY WEEK':
        v = 7
    elif v == 'JULY 4th':
        v = 8
    elif v == 'MARDI GRAS':
        v = 9
    elif v == 'MARTIN LUTHER KING JUNIOR DAY':
        v = 10
    elif v == 'MEMORIAL DAY':
        v = 11
    elif v == 'PRESIDENTS WEEK':
        v = 12
    elif v == 'SEPTEMBER LOW':
        v = 13
    elif v == 'SPRING':
        v = 14
    elif v == 'SUMMER BREAK':
        v = 15
    elif v == 'THANKSGIVING':
        v = 16
    elif v == 'WINTER':
        v = 17
    else:
        v = 18
    meta20.iat[i,7] = v
    
meta20['SEASON'] = meta20['SEASON'].astype(int)

# %%
# Restrict to only necesary metadata
meta_season = meta[['DAYOFWEEK','SEASON','MKHOURSEMH','EPHOURSEMH','HSHOURSEMH','AKHOURSEMH','WDWMINTEMP_mean','WEATHER_WDWPRECIP']]
# Split data to train and test sets
train_season, test_season = train_test_split(meta_season)
# K-means cluster on train set
kmeans_season = KMeans(n_clusters=35, random_state=0).fit(train_season)

# %%
meta
# Out:
#            DATE WDW_TICKET_SEASON  DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  \
# 0    2015-01-01               NaN          5          0           0
# 1    2015-01-02               NaN          6          1           0
# 2    2015-01-03               NaN          7          2           0
# 3    2015-01-04               NaN          1          3           1
# 4    2015-01-05               NaN          2          4           1
# ...         ...               ...        ...        ...         ...
# 1820 2019-12-26               NaN          5        359          51
# 1821 2019-12-27               NaN          6        360          51
# 1822 2019-12-28               NaN          7        361          51
# 1823 2019-12-29               NaN          1        362          52
# 1824 2019-12-30               NaN          2        363          52
#
#       MONTHOFYEAR  YEAR  SEASON  HOLIDAYPX  HOLIDAYM  ... HSFIREWKS  AKPRDDAY  \
# 0               1  2015       2          0         5  ...         1         0
# 1               1  2015       1          2         5  ...         1         0
# 2               1  2015       1          3         0  ...         1         0
# 3               1  2015       1          4         0  ...         1         0
# 4               1  2015       1          5         0  ...         1         0
# ...           ...   ...     ...        ...       ...  ...       ...       ...
# 1820           12  2019       1          2         5  ...         1         0
# 1821           12  2019       2          3         5  ...         1         0
# 1822           12  2019       2          4         5  ...         1         0
# 1823           12  2019       2          3         5  ...         1         0
# 1824           12  2019       2          2         5  ...         1         0
#
#      AKPRDDT1 AKPRDDT2 AKPRDDN  AKFIREN  AKSHWNGT AKSHWNT1  AKSHWNT2  \
# 0         NaN      NaN     NaN      NaN         0      NaN       NaN
# 1         NaN      NaN     NaN      NaN         0      NaN       NaN
# 2         NaN      NaN     NaN      NaN         0      NaN       NaN
# 3         NaN      NaN     NaN      NaN         0      NaN       NaN
# 4         NaN      NaN     NaN      NaN         0      NaN       NaN
# ...       ...      ...     ...      ...       ...      ...       ...
# 1820      NaN      NaN     NaN      NaN         2    18:30     20:00
# 1821      NaN      NaN     NaN      NaN         3    18:30     20:00
# 1822      NaN      NaN     NaN      NaN         3    18:30     20:00
# 1823      NaN      NaN     NaN      NaN         3    18:30     20:00
# 1824      NaN      NaN     NaN      NaN         3    18:30     20:00
#
#               AKSHWNN
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 1820  Rivers of Light
# 1821  Rivers of Light
# 1822  Rivers of Light
# 1823  Rivers of Light
# 1824  Rivers of Light
#
# [1825 rows x 190 columns]

# %%
# Number of days in each grouping
counts = []
for i in range(35):
    counts.append(len(kmeans_season.labels_[kmeans_season.labels_==i]))
print(counts)
# Out:
# [26, 47, 45, 30, 29, 54, 14, 28, 41, 29, 38, 40, 35, 37, 51, 95, 53, 28, 78, 28, 43, 31, 57, 34, 77, 34, 21, 32, 33, 22, 40, 28, 36, 28, 26]

# %%
count = pd.DataFrame(counts, columns = ["COUNTS"])

# %%
train_season["CLUSTER"] = kmeans_season.labels_
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
train_season[train_season["CLUSTER"] == 5]
# Out:
#       DAYOFWEEK  SEASON  MKHOURSEMH  EPHOURSEMH  HSHOURSEMH  AKHOURSEMH  \
# 966           5      13       13.00        13.0        12.0        12.5
# 1352          6      13       10.00        13.0        11.5        11.5
# 1695          6      13       10.00        12.0        12.0        12.5
# 980           5      13       10.00        13.0        12.0        12.0
# 1343          4      13       14.00        12.0        11.5        11.5
# 1331          6      13       10.00        12.0        15.5        12.5
# 626           1      13       10.00        12.0        12.5        12.0
# 1617          5      14       13.00        13.0        12.0        12.0
# 1355          2      13       12.00        12.0        12.5        12.0
# 251           4      13       12.00        12.0        11.0         9.0
# 1354          1      13        9.00        12.0        13.0        12.0
# 258           4      13       12.00        12.0        10.5         9.0
# 1338          6      13       10.00        13.0        13.0        11.5
# 1350          4      13       14.00        12.0        11.5        11.5
# 623           5      13       13.00        13.0        12.0        12.0
# 1335          3      13       10.25        14.0        13.0        11.5
# 965           4      13       13.00        12.0        12.0        12.5
# 986           4      13       14.00        12.0        12.0        12.0
# 1349          3      13       10.25        14.0        11.5        11.5
# 981           6      13       13.00        13.0        12.0        12.0
# 1638          5      14       13.00        13.0        12.0        13.0
# 974           6      13       11.00        13.0        12.0        12.5
# 1693          4      13       13.00        12.0        13.5        12.5
# 973           5      13       12.00        13.0        12.0        12.5
# 615           4      13       14.00        12.0        12.0        12.0
# 621           3      13       10.00        14.0        12.0        12.0
# 985           3      13       11.25        14.0        12.0        12.0
# 1351          5      13       12.00        13.0        11.5        11.5
# 253           6      13       10.00        14.0        11.0         8.0
# 979           4      13       14.00        12.0        12.0        12.0
# 978           3      13       13.25        14.0        12.0        12.0
# 1342          3      13       13.25        14.0        11.5        11.5
# 150           1      14        9.00        12.0        14.0        12.0
# 977           2      13       12.00        12.0        12.0        13.0
# 983           1      13       11.25        12.0        13.0        12.0
# 1694          5      13       13.00        13.0        12.0        11.5
# 987           5      13       12.00        13.0        12.0        12.0
# 967           6      13       11.00        12.0        12.0        12.5
# 1692          3      13       10.25        14.0        12.0        12.5
# 1699          3      13       10.25        14.0        11.5        12.5
# 1344          5      13       12.00        13.0        11.5        11.5
# 616           5      13       10.00        13.0        12.0        12.0
# 1348          2      13       12.00        12.0        11.5        12.5
# 619           1      13       10.00        12.0        13.0        12.0
# 257           3      13       10.00        13.0        10.5         8.0
# 609           5      13       12.00        13.0        12.0        14.0
# 624           6      13       11.00        13.0        14.0        12.0
# 1336          4      13       14.00        12.0        13.0        11.5
# 1624          5      14       13.00        13.0        12.0        13.0
# 262           1      13       10.00        14.0        10.5         9.0
# 982           7      13       12.00        12.0        10.0        11.0
# 1631          5      14       13.00        13.0        12.0        13.0
# 1659          5      15       13.00        13.0        12.0        12.0
# 1337          5      13       12.00        13.0        13.0        11.5
#
#       WDWMINTEMP_mean  WEATHER_WDWPRECIP  CLUSTER
# 966         75.127143               0.28        5
# 1352        74.514286               0.19        5
# 1695        75.524286               0.23        5
# 980         74.064286               0.24        5
# 1343        74.527143               0.20        5
# 1331        75.127143               0.28        5
# 626         73.606429               0.20        5
# 1617        72.320000               0.28        5
# 1355        74.024286               0.19        5
# 251         74.342143               0.24        5
# 1354        74.173571               0.20        5
# 258         74.173571               0.20        5
# 1338        75.058571               0.28        5
# 1350        74.734286               0.24        5
# 623         74.173571               0.20        5
# 1335        75.189286               0.23        5
# 965         75.524286               0.23        5
# 986         74.200000               0.24        5
# 1349        74.593571               0.23        5
# 981         74.050000               0.23        5
# 1638        74.407143               0.28        5
# 974         74.567143               0.27        5
# 1693        75.816429               0.24        5
# 973         75.058571               0.28        5
# 615         74.050000               0.23        5
# 621         74.514286               0.19        5
# 985         74.734286               0.24        5
# 1351        74.200000               0.24        5
# 253         74.593571               0.23        5
# 979         74.572857               0.23        5
# 978         74.527143               0.20        5
# 1342        74.487143               0.24        5
# 150         71.242857               0.20        5
# 977         74.487143               0.24        5
# 983         74.950714               0.24        5
# 1694        75.595000               0.28        5
# 987         74.514286               0.19        5
# 967         75.850714               0.23        5
# 1692        75.475000               0.23        5
# 1699        75.302857               0.28        5
# 1344        74.572857               0.23        5
# 616         74.342143               0.24        5
# 1348        74.950714               0.24        5
# 619         74.734286               0.24        5
# 257         74.125714               0.24        5
# 609         74.577857               0.24        5
# 624         74.024286               0.19        5
# 1336        75.595714               0.28        5
# 1624        72.762143               0.32        5
# 262         73.062857               0.19        5
# 982         74.342143               0.24        5
# 1631        73.985000               0.35        5
# 1659        74.490714               0.19        5
# 1337        74.609286               0.23        5

# %%
test_preds = kmeans_season.predict(test_season)

# %%
# Number of days in each grouping
test_counts = []
for i in range(35):
    test_counts.append(len(test_preds[test_preds==i]))
print(test_counts)
# Out:
# [11, 20, 23, 4, 10, 16, 4, 7, 23, 15, 8, 11, 8, 7, 16, 29, 26, 7, 34, 8, 15, 10, 14, 15, 26, 11, 6, 8, 9, 7, 16, 7, 12, 8, 6]

# %%
test_count = pd.DataFrame(test_counts, columns = ["COUNTS"])
test_count
# Out:
#     COUNTS
# 0       11
# 1       20
# 2       23
# 3        4
# 4       10
# 5       16
# 6        4
# 7        7
# 8       23
# 9       15
# 10       8
# 11      11
# 12       8
# 13       7
# 14      16
# 15      29
# 16      26
# 17       7
# 18      34
# 19       8
# 20      15
# 21      10
# 22      14
# 23      15
# 24      26
# 25      11
# 26       6
# 27       8
# 28       9
# 29       7
# 30      16
# 31       7
# 32      12
# 33       8
# 34       6

# %%
test_season["PREDS"] = test_preds
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
test_season["DATE"] = meta.iloc[test_season.index,0]
train_season["DATE"] = meta.iloc[train_season.index,0]
train_season = train_season.sort_values(by="DATE")
test_season = test_season.sort_values(by="DATE")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train_season.to_csv('clean/train.csv', index=False)
test_season.to_csv('clean/test.csv', index=False)

# %%
train_season[890:920]
# Out:
#       DAYOFWEEK  SEASON  MKHOURSEMH  EPHOURSEMH  HSHOURSEMH  AKHOURSEMH  \
# 1176          5      14       14.00        13.0        12.0        13.5
# 1177          6       4       16.00        12.0        12.0        13.5
# 1178          7       4       15.00        12.0        12.0        15.0
# 1179          1       4       14.25        12.0        13.0        15.0
# 1180          2       4       16.00        12.0        12.0        16.0
# 1181          3       4       16.00        14.0        12.0        15.0
# 1182          4       4       16.00        12.0        12.0        15.0
# 1183          5       4       16.00        13.0        12.0        15.0
# 1184          6       4       17.00        12.0        12.0        15.0
# 1185          7       4       15.00        12.0        12.0        16.0
# 1186          1       4       15.00        12.0        13.0        14.0
# 1187          2       4       16.00        12.0        12.0        16.0
# 1188          3       4       16.00        14.0        12.0        14.5
# 1189          4       4       16.00        12.0        12.0        14.5
# 1190          5       4       16.00        13.0        12.0        14.5
# 1191          6       4       17.00        12.0        12.0        14.5
# 1192          7       4       16.00        12.0        12.0        16.0
# 1193          1       4       14.00        12.0        13.0        12.5
# 1194          2       4       14.00        12.0        12.0        13.5
# 1196          4      14       13.00        12.0        12.0        12.5
# 1197          5      14       13.00        13.0        12.0        12.5
# 1198          6      14       14.00        12.0        12.0        12.5
# 1199          7      14       16.00        12.0        12.0        13.5
# 1200          1      14       15.25        12.0        13.0        12.5
# 1201          2      14       13.00        12.0        12.0        13.5
# 1202          3      14       13.00        14.0        12.0        11.5
# 1203          4      14       13.00        12.0        12.0        12.5
# 1204          5      14       13.00        13.0        12.0        12.5
# 1207          1      14       13.00        12.0        12.0        13.0
# 1208          2      14       14.00        12.0        12.0        13.5
#
#       WDWMINTEMP_mean  WEATHER_WDWPRECIP  CLUSTER       DATE
# 1176        56.607857               0.12        8 2018-03-22
# 1177        58.960714               0.12       21 2018-03-23
# 1178        59.092857               0.11       28 2018-03-24
# 1179        58.370714               0.12        4 2018-03-25
# 1180        57.860714               0.12        4 2018-03-26
# 1181        57.092143               0.12        2 2018-03-27
# 1182        57.527143               0.12       21 2018-03-28
# 1183        58.542857               0.07       21 2018-03-29
# 1184        58.102857               0.12       21 2018-03-30
# 1185        60.530714               0.08       28 2018-03-31
# 1186        61.665714               0.12        4 2018-04-01
# 1187        62.538571               0.12        4 2018-04-02
# 1188        63.500769               0.12        4 2018-04-03
# 1189        63.077143               0.07       28 2018-04-04
# 1190        61.104286               0.12       28 2018-04-05
# 1191        59.731429               0.08       28 2018-04-06
# 1192        60.682857               0.08       28 2018-04-07
# 1193        60.561429               0.08        4 2018-04-08
# 1194        60.997143               0.08        4 2018-04-09
# 1196        61.970714               0.08       27 2018-04-11
# 1197        62.827143               0.03       27 2018-04-12
# 1198        62.401429               0.08       27 2018-04-13
# 1199        63.136154               0.08       27 2018-04-14
# 1200        63.005714               0.04       25 2018-04-15
# 1201        60.360000               0.04       27 2018-04-16
# 1202        61.352857               0.12       27 2018-04-17
# 1203        62.056429               0.08       27 2018-04-18
# 1204        63.994286               0.08       25 2018-04-19
# 1207        64.005000               0.12       25 2018-04-22
# 1208        64.209286               0.08       25 2018-04-23

# %%
train_season[train_season["CLUSTER"]==24]

# %%
test_season
# Out:
#       DAYOFWEEK  SEASON  MKHOURSEMH  EPHOURSEMH  HSHOURSEMH  AKHOURSEMH  \
# 0             5       2        18.0        13.0        14.0        11.0
# 1             6       1        17.0        15.0        14.0        12.0
# 19            3      10        13.0        13.0        10.0         8.0
# 25            2      17        13.0        12.0         9.0         9.0
# 33            3      17        12.0        13.0        10.0         9.0
# ...         ...     ...         ...         ...         ...         ...
# 1812          4       1        13.0        12.5        14.0        11.0
# 1815          7       1        16.0        12.5        15.0        12.0
# 1817          2       1        17.0        12.5        15.0        14.0
# 1820          5       1        17.0        13.5        16.0        13.0
# 1821          6       2        17.0        12.5        16.0        14.0
#
#       WDWMINTEMP_mean  WEATHER_WDWPRECIP  PREDS       DATE
# 0           53.375714               0.12      2 2015-01-01
# 1           53.750714               0.12      2 2015-01-02
# 19          48.949286               0.12     17 2015-01-20
# 25          51.110000               0.08     11 2015-01-26
# 33          55.148571               0.04     14 2015-02-03
# ...               ...                ...    ...        ...
# 1812        56.152143               0.12      2 2019-12-18
# 1815        56.849286               0.12      2 2019-12-21
# 1817        57.052857               0.12      2 2019-12-23
# 1820        55.557143               0.07      2 2019-12-26
# 1821        55.070000               0.08      2 2019-12-27
#
# [457 rows x 10 columns]

# %%
# Read in 2020 metadata
meta20 = pd.read_csv("2020/metadata.csv")
meta20["DATE"] = pd.to_datetime(meta20["DATE"])
meta20 = meta20.drop_duplicates()
meta20.index = range(len(meta20))
# meta20 = meta20[(meta20["DATE"] >= pd.Timestamp(2019, 10, 31)) |((meta20["DATE"] >= pd.Timestamp(2019, 7, 13)) & (meta20["DATE"] <= pd.Timestamp(2019, 7, 20)))]
meta20 = meta20[(meta20["DATE"] >= pd.Timestamp(2019, 1, 1)) & (meta20["DATE"] <= pd.Timestamp(2019, 3, 13))]
meta20
# Out:
#            DATE WDW_TICKET_SEASON  DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  \
# 1461 2019-01-01              peak          3          0           0
# 1462 2019-01-02              peak          4          1           0
# 1463 2019-01-03              peak          5          2           0
# 1464 2019-01-04              peak          6          3           0
# 1465 2019-01-05              peak          7          4           0
# ...         ...               ...        ...        ...         ...
# 1528 2019-03-09              peak          7         67           9
# 1529 2019-03-10           regular          1         68          10
# 1530 2019-03-11           regular          2         69          10
# 1531 2019-03-12             value          3         70          10
# 1532 2019-03-13             value          4         71          10
#
#       MONTHOFYEAR  YEAR          SEASON  HOLIDAYPX  HOLIDAYM  ... HSFIREWKS  \
# 1461            1  2019  CHRISTMAS PEAK          0         5  ...         1
# 1462            1  2019       CHRISTMAS          2         5  ...         1
# 1463            1  2019       CHRISTMAS          3         0  ...         1
# 1464            1  2019       CHRISTMAS          4         0  ...         1
# 1465            1  2019       CHRISTMAS          5         0  ...         1
# ...           ...   ...             ...        ...       ...  ...       ...
# 1528            3  2019          SPRING          4         0  ...         1
# 1529            3  2019          SPRING          5         0  ...         1
# 1530            3  2019          SPRING          6         0  ...         1
# 1531            3  2019          SPRING          6         0  ...         1
# 1532            3  2019          SPRING          5         0  ...         1
#
#       AKPRDDAY AKPRDDT1 AKPRDDT2 AKPRDDN  AKFIREN  AKSHWNGT AKSHWNT1  \
# 1461         0      NaN      NaN     NaN      NaN         2    18:30
# 1462         0      NaN      NaN     NaN      NaN         2    18:30
# 1463         0      NaN      NaN     NaN      NaN         2    18:30
# 1464         0      NaN      NaN     NaN      NaN         2    18:30
# 1465         0      NaN      NaN     NaN      NaN         2    18:30
# ...        ...      ...      ...     ...      ...       ...      ...
# 1528         0      NaN      NaN     NaN      NaN         2    19:15
# 1529         0      NaN      NaN     NaN      NaN         2    20:15
# 1530         0      NaN      NaN     NaN      NaN         2    20:15
# 1531         0      NaN      NaN     NaN      NaN         2    20:15
# 1532         0      NaN      NaN     NaN      NaN         2    20:15
#
#       AKSHWNT2          AKSHWNN
# 1461     20:00  Rivers of Light
# 1462     20:00  Rivers of Light
# 1463     20:00  Rivers of Light
# 1464     20:00  Rivers of Light
# 1465     20:00  Rivers of Light
# ...        ...              ...
# 1528     20:30  Rivers of Light
# 1529     21:30  Rivers of Light
# 1530     21:30  Rivers of Light
# 1531     21:30  Rivers of Light
# 1532     21:30  Rivers of Light
#
# [72 rows x 190 columns]

# %%
# Restrict to only necesary metadata
meta20_test = meta20[['DAYOFWEEK','SEASON','MKHOURSEMH','EPHOURSEMH','HSHOURSEMH','AKHOURSEMH','WDWMINTEMP_mean','WEATHER_WDWPRECIP']]
test20_preds = kmeans_season.predict(meta20_test)
test20_preds
# Out:
# array([ 2,  2, 19, 19, 19, 19, 19, 19, 19, 14, 13, 13, 11, 11, 11, 11, 17,
#        17, 17, 17, 31, 31, 17, 17, 17, 13, 14, 14, 11, 11, 11, 11, 13, 14,
#        14, 14, 14, 30, 13, 13, 14, 11, 14, 11, 17, 26, 26, 31, 31, 31,  3,
#         3, 27, 27, 27,  6, 30, 14, 30,  8,  8, 31, 31, 31, 26,  3, 26, 13,
#        22, 22, 22, 22], dtype=int32)

# %%
meta20_test["PREDS"] = test20_preds
meta20_test
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       DAYOFWEEK  SEASON  MKHOURSEMH  EPHOURSEMH  HSHOURSEMH  AKHOURSEMH  \
# 1461          3       2       14.00        14.0        11.0        13.0
# 1462          4       1       14.00        12.0        12.5        14.0
# 1463          5       1       14.00        13.0        11.0        13.0
# 1464          6       1       15.00        12.0        11.0        13.0
# 1465          7       1       14.00        12.0        11.0        13.0
# ...         ...     ...         ...         ...         ...         ...
# 1528          7      14       14.00        12.0        11.0        13.0
# 1529          1      14       14.25        12.0        12.5        12.0
# 1530          2      14       13.00        12.0        13.0        13.0
# 1531          3      14       15.25        14.0        11.5        12.0
# 1532          4      14       14.00        12.0        13.0        12.0
#
#       WDWMINTEMP_mean  WEATHER_WDWPRECIP  PREDS
# 1461        53.375714               0.12      2
# 1462        53.750714               0.12      2
# 1463        49.212857               0.07     19
# 1464        48.270714               0.12     19
# 1465        48.971538               0.12     19
# ...               ...                ...    ...
# 1528        53.685714               0.15     13
# 1529        56.999286               0.16     22
# 1530        58.840000               0.12     22
# 1531        59.466429               0.16     22
# 1532        56.789286               0.07     22
#
# [72 rows x 9 columns]

# %%
meta20_test["DATE"] = meta.iloc[meta20_test.index,0]
meta20_test = meta20_test.sort_values(by="DATE")
meta20_test
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       DAYOFWEEK  SEASON  MKHOURSEMH  EPHOURSEMH  HSHOURSEMH  AKHOURSEMH  \
# 1461          3       2       14.00        14.0        11.0        13.0
# 1462          4       1       14.00        12.0        12.5        14.0
# 1463          5       1       14.00        13.0        11.0        13.0
# 1464          6       1       15.00        12.0        11.0        13.0
# 1465          7       1       14.00        12.0        11.0        13.0
# ...         ...     ...         ...         ...         ...         ...
# 1528          7      14       14.00        12.0        11.0        13.0
# 1529          1      14       14.25        12.0        12.5        12.0
# 1530          2      14       13.00        12.0        13.0        13.0
# 1531          3      14       15.25        14.0        11.5        12.0
# 1532          4      14       14.00        12.0        13.0        12.0
#
#       WDWMINTEMP_mean  WEATHER_WDWPRECIP  PREDS       DATE
# 1461        53.375714               0.12      2 2019-01-01
# 1462        53.750714               0.12      2 2019-01-02
# 1463        49.212857               0.07     19 2019-01-03
# 1464        48.270714               0.12     19 2019-01-04
# 1465        48.971538               0.12     19 2019-01-05
# ...               ...                ...    ...        ...
# 1528        53.685714               0.15     13 2019-03-09
# 1529        56.999286               0.16     22 2019-03-10
# 1530        58.840000               0.12     22 2019-03-11
# 1531        59.466429               0.16     22 2019-03-12
# 1532        56.789286               0.07     22 2019-03-13
#
# [72 rows x 10 columns]

# %%
for i in range(len(meta20_test)):
    meta20_test.iat[i,9] = meta20_test.iloc[i]["DATE"].replace(year=2020)
    
meta20_test
# Out:
#       DAYOFWEEK  SEASON  MKHOURSEMH  EPHOURSEMH  HSHOURSEMH  AKHOURSEMH  \
# 1461          3       2       14.00        14.0        11.0        13.0
# 1462          4       1       14.00        12.0        12.5        14.0
# 1463          5       1       14.00        13.0        11.0        13.0
# 1464          6       1       15.00        12.0        11.0        13.0
# 1465          7       1       14.00        12.0        11.0        13.0
# ...         ...     ...         ...         ...         ...         ...
# 1528          7      14       14.00        12.0        11.0        13.0
# 1529          1      14       14.25        12.0        12.5        12.0
# 1530          2      14       13.00        12.0        13.0        13.0
# 1531          3      14       15.25        14.0        11.5        12.0
# 1532          4      14       14.00        12.0        13.0        12.0
#
#       WDWMINTEMP_mean  WEATHER_WDWPRECIP  PREDS       DATE
# 1461        53.375714               0.12      2 2020-01-01
# 1462        53.750714               0.12      2 2020-01-02
# 1463        49.212857               0.07     19 2020-01-03
# 1464        48.270714               0.12     19 2020-01-04
# 1465        48.971538               0.12     19 2020-01-05
# ...               ...                ...    ...        ...
# 1528        53.685714               0.15     13 2020-03-09
# 1529        56.999286               0.16     22 2020-03-10
# 1530        58.840000               0.12     22 2020-03-11
# 1531        59.466429               0.16     22 2020-03-12
# 1532        56.789286               0.07     22 2020-03-13
#
# [72 rows x 10 columns]

# %%
meta20_test.to_csv('clean/test20pre.csv', index=False)
